# %%
# check installed version
import pycaret
pycaret.__version__
# Out:
# '3.3.2'

# %%
# !pip install numpy==1.26.4
# !python -m pip install -U pip setuptools wheel
# !python -m pip install --force-reinstall "scipy==1.10.1"
# !python -m pip install --force-reinstall "scikit-plot==0.3.7" "pycaret"
# !python -m pip install --force-reinstall "pandas==2.1.4"

# %%
# loading sample dataset from pycaret dataset module
from pycaret.datasets import get_data
data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# import pycaret classification and init setup
from pycaret.classification import *
s = setup(data, target = 'species', session_id = 123)
# Out:
# <style type="text/css">
# #T_e7291_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e7291">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7291_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e7291_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7291_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7291_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e7291_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e7291_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7291_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e7291_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_e7291_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# compare baseline models
best = compare_models()
# Out:
# <style type="text/css">
# #T_3bbc9 th {
#   text-align: left;
# }
# ...

# %%
# plot confusion matrix
plot_model(best, plot = 'confusion_matrix')

# %%
# plot AUC
plot_model(best, plot = 'auc')

# %%
# plot feature importance
plot_model(best, plot = 'feature')

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# predict on test set
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_13c5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13c5b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_13c5b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_13c5b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_13c5b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_13c5b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_13c5b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_13c5b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_13c5b_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13c5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13c5b_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...

# %%
# show predictions df
holdout_pred.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species  \
# 72            6.3          2.5           4.9          1.5  Iris-versicolor
# 125           7.2          3.2           6.0          1.8   Iris-virginica
# 80            5.5          2.4           3.8          1.1  Iris-versicolor
# 86            6.7          3.1           4.7          1.5  Iris-versicolor
# 117           7.7          3.8           6.7          2.2   Iris-virginica
#
#     prediction_label  prediction_score
# 72   Iris-versicolor            0.5203
# 125   Iris-virginica            0.9503
# 80   Iris-versicolor            0.9334
# 86   Iris-versicolor            0.7320
# 117   Iris-virginica            0.9953

# %%
# copy data and drop Class variable

new_data = data.copy()
new_data.drop('species', axis=1, inplace=True)
new_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# predict model on new_data
predictions = predict_model(best, data = new_data)
predictions.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width prediction_label  \
# 0           5.1          3.5           1.4          0.2      Iris-setosa
# 1           4.9          3.0           1.4          0.2      Iris-setosa
# 2           4.7          3.2           1.3          0.2      Iris-setosa
# 3           4.6          3.1           1.5          0.2      Iris-setosa
# 4           5.0          3.6           1.4          0.2      Iris-setosa
#
#    prediction_score
# 0            0.9775
# 1            0.9678
# 2            0.9820
# 3            0.9719
# 4            0.9813
